# %% [markdown]
# <a href="https://colab.research.google.com/github/PeterMamdouh678/Market-Analysis/blob/main/Market_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Question 1: read the data from the excel file**

# %%
import pandas as pd
customer = pd.read_excel("customer.xlsx")

# %% [markdown]
# **a) show the first five columns**

# %%
customer.head()
# Out:
#     No    ID  Age  ... NumWebPurchases NumCatalogPurchases  NumStorePurchases
# 0  193  7829  121  ...               2                   1                  2
# 1   40  2968   79  ...               7                  10                  5
# 2  104  9370   77  ...               6                   3                  6
# 3  162  9260   77  ...              10                   6                  9
# 4   16  2114   76  ...               7                   6                 12
#
# [5 rows x 12 columns]

# %% [markdown]
# **b) show last five columns**

# %%
customer.tail()
# Out:
#       No    ID  Age  ... NumWebPurchases NumCatalogPurchases  NumStorePurchases
# 194  112  7431   30  ...               7                   4                  5
# 195  114   999   30  ...               6                   7                 11
# 196  141   821   29  ...               5                   4                 12
# 197   47  9909   25  ...               3                   1                  3
# 198   39  8595    8  ...               1                   1                  3
#
# [5 rows x 12 columns]

# %%
display(customer)
# Out:
#       No    ID  Age  ... NumWebPurchases NumCatalogPurchases  NumStorePurchases
# 0    193  7829  121  ...               2                   1                  2
# 1     40  2968   79  ...               7                  10                  5
# 2    104  9370   77  ...               6                   3                  6
# 3    162  9260   77  ...              10                   6                  9
# 4     16  2114   76  ...               7                   6                 12
# ..   ...   ...  ...  ...             ...                 ...                ...
# 194  112  7431   30  ...               7                   4                  5
# 195  114   999   30  ...               6                   7                 11
# 196  141   821   29  ...               5                   4                 12
# 197   47  9909   25  ...               3                   1                  3
# 198   39  8595    8  ...               1                   1                  3
#
# ...

# %% [markdown]
# Clean Data {replacing data}

# %%
customer.dropna(how = 'all',inplace = True)

# %%
customer.dropna(how = 'all',axis =1,inplace = True)

# %%
customer.fillna(0,inplace = True)

# %%
# customer['Income']=customer['Income'].astype(int)

# %%
# customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199 entries, 0 to 198
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   No                 199 non-null    int64
#  1   ID                 199 non-null    int64
#  2   Age                199 non-null    int64
#  3   Education          199 non-null    object
#  4   Marital_Status     199 non-null    object
#  5   Income             199 non-null    int64
#  6   Kidhome            199 non-null    int64
#  7   Teenhome           199 non-null    int64
#  8   Dt_Customer        199 non-null    datetime64[ns]
#  9   Web_Purchases      199 non-null    int64
#  10  Catalog_Purchases  199 non-null    int64
#  11  Store_Purchases    199 non-null    int64
#  12  incomeAverage      199 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(9), object(2)
# memory usage: 21.8+ KB

# %% [markdown]
# Renaming Columns

# %%
customer.rename(columns={"NumWebPurchases":"Web_Purchases",
                         "NumCatalogPurchases":"Catalog_Purchases",
                         "NumStorePurchases":"Store_Purchases"}, inplace=True)

# %% [markdown]
# **Question 2 : Sort the Income in a descending order [largest to smallest] and AGE in ascending order [smallest to largest]**

# %%
customer.sort_values(['Income','Age'], ascending=[0,1])
# Out:
#       No     ID  Age  ... Catalog_Purchases Store_Purchases  incomeAverage
# 121  165   8475   48  ...                22               0   52087.792553
# 171  125   7215   38  ...                 8              13   52087.792553
# 196  141    821   29  ...                 4              12   52087.792553
# 105  117   1592   51  ...                 6               5   52087.792553
# 62   110  10991   61  ...                 4               4   52087.792553
# ..   ...    ...  ...  ...               ...             ...            ...
# 66   129   8268   59  ...                 1               7   52087.792553
# 50    44   7281   63  ...                 3               4   52087.792553
# 38    91   8996   65  ...                 2               8   52087.792553
# 39    92   9235   65  ...                 0               2   52087.792553
# 16    49   7244   70  ...                 1               4   52087.792553
#
# [199 rows x 13 columns]

# %% [markdown]
# **Q3) Group by Income and Web_Purchases columns from the data**

# %%
customer.groupby(['Income','Web_Purchases']).mean()
# Out:
#                          No            ID  ...  Store_Purchases  incomeAverage
# Income Web_Purchases                       ...
# 0      1               49.0   6170.000000  ...         2.666667   52087.792553
#        2               67.0   7199.666667  ...         5.000000   52087.792553
#        3               72.0  10629.000000  ...         3.000000   52087.792553
#        6              131.5   4781.500000  ...         7.000000   52087.792553
#        7               91.0   8996.000000  ...         8.000000   52087.792553
# ...                     ...           ...  ...              ...            ...
# 89058  5              110.0  10991.000000  ...         4.000000   52087.792553
# 90765  4              117.0   1592.000000  ...         5.000000   52087.792553
# 92859  5              141.0    821.000000  ...        12.000000   52087.792553
# 101970 6              125.0   7215.000000  ...        13.000000   52087.792553
# ...

# %% [markdown]
# **Q4) Using the data in the excel add a column to find the average income**

# %%
customer['incomeAverage'] = customer["Income"].mean()
customer
# Out:
#       No    ID  Age  ... Catalog_Purchases Store_Purchases  incomeAverage
# 0    193  7829  121  ...                 1               2   49208.567839
# 1     40  2968   79  ...                10               5   49208.567839
# 2    104  9370   77  ...                 3               6   49208.567839
# 3    162  9260   77  ...                 6               9   49208.567839
# 4     16  2114   76  ...                 6              12   49208.567839
# ..   ...   ...  ...  ...               ...             ...            ...
# 194  112  7431   30  ...                 4               5   49208.567839
# 195  114   999   30  ...                 7              11   49208.567839
# 196  141   821   29  ...                 4              12   49208.567839
# 197   47  9909   25  ...                 1               3   49208.567839
# 198   39  8595    8  ...                 1               3   49208.567839
#
# [199 rows x 13 columns]

# %% [markdown]
# **Q5) visulize the data using the plotiting graph from dataframe "customer" to show the relationship between the Income and the Age**

# %%
import matplotlib.pyplot as plt
customer[['Income','Age']].head(30).plot

# %%
line = customer[['Income','Age']].plot.line( title = "Income vs Age", figsize=(12,18))
line.set_xlabel("Age")
line.set_ylabel("Income")
# Out:
# Text(0, 0.5, 'Income')

# %% [markdown]
# **Q6) The bank asked to find the customers that have more than 30,000 Income**

# %%
# Customers with income more than 30,000

selected_rows = customer['Income']>30000
display(customer.loc[selected_rows,:])
# Out:
#       No    ID  Age  ... Catalog_Purchases Store_Purchases  incomeAverage
# 0    193  7829  121  ...                 1               2   49208.567839
# 1     40  2968   79  ...                10               5   49208.567839
# 2    104  9370   77  ...                 3               6   49208.567839
# 3    162  9260   77  ...                 6               9   49208.567839
# 4     16  2114   76  ...                 6              12   49208.567839
# ..   ...   ...  ...  ...               ...             ...            ...
# 193  192  5602   32  ...                 7              12   49208.567839
# 194  112  7431   30  ...                 4               5   49208.567839
# 195  114   999   30  ...                 7              11   49208.567839
# 196  141   821   29  ...                 4              12   49208.567839
# 198   39  8595    8  ...                 1               3   49208.567839
#
# [155 rows x 13 columns]

# %%
customer['Marital_Status'].unique()
# Out:
# array(['Divorced', 'Married', 'Single', 'Together', 'Widow', 'Alone'],
#       dtype=object)

# %%
Div = customer[ customer['Marital_Status']=='Divorced' ]
Div['Total_Purchases'].sum()
# Out:
# 222

# %%
Married = customer[ customer['Marital_Status']=='Married' ]
Married['Total_Purchases'].sum()
# Out:
# 1160

# %%
Single = customer[ customer['Marital_Status']=='Single' ]
Single['Total_Purchases'].sum()
# Out:
# 475

# %%
Together = customer[ customer['Marital_Status']=='Together' ]
Together['Total_Purchases'].sum()
# Out:
# 546

# %%
Widow = customer[ customer['Marital_Status']=='Widow' ]
Widow['Total_Purchases'].sum()
# Out:
# 56

# %%
Alone = customer[ customer['Marital_Status']=='Alone' ]
Alone['Total_Purchases'].sum()
# Out:
# 29

# %%
# total purchases per customer

customer['Total_Purchases']= customer['Web_Purchases'] + customer['Catalog_Purchases'] + customer['Store_Purchases']
display(customer)
# Out:
#       No    ID  Age  ... Store_Purchases incomeAverage  Total_Purchases
# 0    193  7829  121  ...               2  49208.567839                5
# 1     40  2968   79  ...               5  49208.567839               22
# 2    104  9370   77  ...               6  49208.567839               15
# 3    162  9260   77  ...               9  49208.567839               25
# 4     16  2114   76  ...              12  49208.567839               25
# ..   ...   ...  ...  ...             ...           ...              ...
# 194  112  7431   30  ...               5  49208.567839               16
# 195  114   999   30  ...              11  49208.567839               24
# 196  141   821   29  ...              12  49208.567839               21
# 197   47  9909   25  ...               3  49208.567839                7
# 198   39  8595    8  ...               3  49208.567839                5
#
# [199 rows x 14 columns]

# %%
High_Purchases = customer['Total_Purchases']>=25
display(customer.loc[High_Purchases,:])
# Out:
#       No    ID  Age  ... Store_Purchases incomeAverage  Total_Purchases
# 3    162  9260   77  ...               9  49208.567839               25
# 4     16  2114   76  ...              12  49208.567839               25
# 36    56  6260   66  ...              13  49208.567839               26
# 51    73  6312   63  ...              13  49208.567839               26
# 71    52  4114   57  ...              13  49208.567839               28
# 76    30  1966   56  ...              10  49208.567839               25
# 130  176  8717   46  ...               8  49208.567839               27
# 153   22  5376   42  ...               0  49208.567839               28
# 154   68  9369   42  ...              10  49208.567839               31
# 155  103  4518   42  ...              11  49208.567839               25
# 171  125  7215   38  ...              13  49208.567839               27
# 182   28  5255   35  ...               0  49208.567839               27
# ...

# %%
Low_Purchases = customer['Total_Purchases']<=5
display(customer.loc[Low_Purchases,:])
# Out:
#       No     ID  Age  ... Store_Purchases incomeAverage  Total_Purchases
# 0    193   7829  121  ...               2  49208.567839                5
# 13    10   5899   71  ...               0  49208.567839                1
# 15    36  10738   70  ...               3  49208.567839                5
# 30     2   2174   67  ...               2  49208.567839                4
# 39    92   9235   65  ...               2  49208.567839                3
# 45   161   2795   64  ...               2  49208.567839                3
# 48    43   8430   64  ...               3  49208.567839                3
# 52   102   1016   63  ...               3  49208.567839                5
# 57   179  10492   63  ...               3  49208.567839                3
# 59    86   5268   61  ...               4  49208.567839                5
# 61   101   1473   61  ...               3  49208.567839                5
# 63   185   2563   60  ...               3  49208.567839                5
# ...

# %%
# Mid purchases customers

Mid_Purchases = customer[ (customer['Total_Purchases']>5) & (customer['Total_Purchases']<25) ]
Mid_Purchases.count()
# Out:
# No                   134
# ID                   134
# Age                  134
# Education            134
# Marital_Status       134
# Income               134
# Kidhome              134
# Teenhome             134
# Dt_Customer          134
# Web_Purchases        134
# Catalog_Purchases    134
# Store_Purchases      134
# incomeAverage        134
# Total_Purchases      134
# dtype: int64

# %% [markdown]
# َ**Q7) Show the maximum and minimum customer

# %%
customer.max()
# Out:
# No                                   199
# ID                                 11178
# Age                                  121
# Education                            PhD
# Marital_Status                     Widow
# Income                            157243
# Kidhome                                2
# Teenhome                               2
# Dt_Customer          2014-06-28 00:00:00
# Web_Purchases                         27
# Catalog_Purchases                     28
# Store_Purchases                       13
# incomeAverage                    49208.6
# Total_Purchases                       31
# dtype: object

# %%
customer.min()
# Out:
# No                                     1
# ID                                    92
# Age                                    8
# Education                       2n Cycle
# Marital_Status                     Alone
# Income                                 0
# Kidhome                                0
# Teenhome                               0
# Dt_Customer          2012-08-08 00:00:00
# Web_Purchases                          0
# Catalog_Purchases                      0
# Store_Purchases                        0
# incomeAverage                    49208.6
# Total_Purchases                        1
# dtype: object
